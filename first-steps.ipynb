# %% [markdown]
# 1. **Install** the QuanTUK Quantum Computing Education Package using *pip*

# %%
# !pip3 install --quiet --force-reinstall git+https://github.com/QuanTUK/QC-Education-Package.git

# %% [markdown]
# 2. Get all the **examples** in the [DCN_examples Repository](https://github.com/QuanTUK/DCN_examples) using *git clone*

# %%
# !git clone https://github.com/QuanTUK/DCN_examples.git

# %% [markdown]
# 3. Try the package within the next cell and explore other examples starting with the [introduction](introduction.ipynb).

# %%
from qc_education_package import Simulator, CircleNotation, DimensionalCircleNotation

n = 3  # No. of qubits
sim = Simulator(n)  # Create a quantum computer simulator object
sim.write(1)  # write integer 1 in binary -> |001> | LSB right
sim.had(1)  # Apply hadamard gate to qubit 0

# for visualizing
sim = CircleNotation(sim)
sim.show()
